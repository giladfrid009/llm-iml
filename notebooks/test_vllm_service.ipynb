# %%
# fix imports
import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.inference.vllm_service import *

service = VLLMService(
    gpu_ids=[0],
    model_name="meta-llama/Llama-3.2-1B-Instruct",
    host="0.0.0.0",
    port=None,
)

messeges = [
    [
        {"role": "user", "content": "What is the capital of France?"},
        {"role": "assistant", "content": "The capital of France is Paris."},
    ],
    [
        {"role": "user", "content": "What is the largest mammal?"},
        {"role": "assistant", "content": "The largest mammal is the blue whale."},
    ],
]

texts = [
    "What is the capital of France?",
    "What is the largest mammal?",
]

service.start()
chat_answers = service.chat(messeges)         # batched chat
gen_answers  = service.generate(texts)     # batched generate
service.shutdown()

print(f"Chat Answers:", chat_answers)
print(f"Generate Answers:", gen_answers)
# Out:
# INFO:src.inference.vllm_service:[VLLMServer] Launching subprocess:
#     /home/fre.gilad/source/llm-iml/.venv/bin/python /home/fre.gilad/source/llm-iml/src/inference/vllm_server.py --serve --model meta-llama/Llama-3.2-1B-Instruct --host 0.0.0.0 --port 58939 --gpus 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 26
#      10 messeges = [
#      11     [
#      12         {"role": "user", "content": "What is the capital of France?"},
#    (...)
#      18     ],
#      19 ]
#      21 texts = [
#      22     "What is the capital of France?",
#      23     "What is the largest mammal?",
#      24 ]
# ---> 26 service.start()
#      27 chat_answers = service.chat(messeges)         # batched chat
#      28 gen_answers  = service.generate(texts)     # batched generate
#
# File ~/source/llm-iml/src/inference/vllm_service.py:263, in VLLMService.start(self)
#     258 def start(self) -> None:
#     259     """
#     260     1) Start the server subprocess (loads model on GPUs, polls health).
#     261     2) Instantiate VLLMClient pointing to that server.
#     262     """
# --> 263     self.server.start()
#     264     self.client = VLLMClient(host=self.server.host, port=self.server.port, timeout=self.client_timeout)
#
# File ~/source/llm-iml/src/inference/vllm_service.py:140, in VLLMServer.start(self)
#     138 if self._process.poll() is not None:
#     139     out, err = self._process.communicate(timeout=1)
# --> 140     raise RuntimeError("[VLLMServer] Subprocess terminated prematurely.\n" f"STDOUT:\n{out}\nSTDERR:\n{err}")
#     141 # 2) Try health endpoint
#     142 try:
#
# RuntimeError: [VLLMServer] Subprocess terminated prematurely.
# STDOUT:
#
# STDERR:
# Traceback (most recent call last):
#   File "/home/fre.gilad/source/llm-iml/src/inference/vllm_server.py", line 167, in <module>
#     server_main(model_name=args.model, host=args.host, port=args.port, gpus=args.gpus)
#   File "/home/fre.gilad/source/llm-iml/src/inference/vllm_server.py", line 148, in server_main
#     _llm_instance = LLM(model=model_name)
#   File "/home/fre.gilad/source/llm-iml/.venv/lib/python3.10/site-packages/vllm/entrypoints/llm.py", line 144, in __init__
#     self.llm_engine = LLMEngine.from_engine_args(
#   File "/home/fre.gilad/source/llm-iml/.venv/lib/python3.10/site-packages/vllm/engine/llm_engine.py", line 336, in from_engine_args
#     engine_config = engine_args.create_engine_config()
#   File "/home/fre.gilad/source/llm-iml/.venv/lib/python3.10/site-packages/vllm/engine/arg_utils.py", line 630, in create_engine_config
#     model_config = ModelConfig(
#   File "/home/fre.gilad/source/llm-iml/.venv/lib/python3.10/site-packages/vllm/config.py", line 141, in __init__
#     self.max_model_len = _get_and_verify_max_len(
#   File "/home/fre.gilad/source/llm-iml/.venv/lib/python3.10/site-packages/vllm/config.py", line 1283, in _get_and_verify_max_len
#     if rope_scaling is not None and rope_scaling["type"] != "su":
# KeyError: 'type'

# %%
# python circuit-breakers-eval/evaluation/evaluate.py -m meta-llama/Llama-3.2-1B-Instruct --benchmark circuit-breakers-eval/data/harmbench_test_ctx.json --training_ids 0 1 2 --output_dir results/
