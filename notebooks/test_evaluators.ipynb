# %%
# fix imports
import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.eval.evaluator import MultiEvaluator
from src.eval.harmbench_evaluator import HarmbenchEvaluator
from src.eval.llama_evaluator import LlamaEvaluator
from src.eval.template_evaluator import TemplateEvaluator
from src.eval.llama_guard_evaluator import LlamaGuardEvaluator
from src.eval.strong_reject_evaluator import StrongRejectEvaluator
from src.eval.beaver_evaluator import BeaverEvaluator
from gserve.configs import ServeConfig, LLMConfig


evaluators = [
    # HarmbenchEvaluator(
    #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
    #     use_context=False,
    #     silent=False,
    # ),
    # LlamaGuardEvaluator(
    #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=None, client_timeout=60, verbose=True),
    #     # llm_config=LLMConfig(model_name="meta-llama/Llama-Guard-4-12B", max_model_len=4096),
    #     model_name="meta-llama/Llama-Guard-3-1B",
    #     silent=False,
    # ),
    # StrongRejectEvaluator(
    #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
    #     binary_thresh=0.5,
    #     silent=False,
    # ),
    # BeaverEvaluator(
    #     device_map="cuda:1",
    #     binary_thresh=None,
    #     silent=False,
    #     compile=False,
    # ),
    MultiEvaluator(
        [
            BeaverEvaluator(
            device_map="cuda:0",
            binary_thresh=None,
            silent=False,
            compile=False,
            ),
                LlamaEvaluator(
                serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
                silent=False,
            ),
        ],
        combine_fn = lambda res: (res[0] > 5) * res[1]
    )
    # LlamaEvaluator(
    #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
    #     silent=False,
    # ),
    # TemplateEvaluator(
    #     silent=False,
    # ),
]
# Out:
# INFO 06-11 15:13:54 [__init__.py:243] Automatically detected platform cuda.
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# INFO 06-11 15:14:03 [vllm_service.py:153] Launching subprocess:
#     /home/fre.gilad/source/llm-iml/.venv/bin/python /home/fre.gilad/source/llm-iml/.venv/lib/python3.12/site-packages/gserve/vllm_server.py --serve --model meta-llama/Llama-2-7b-chat-hf --host 127.0.0.1 --port 41109 --gpus 1 --llm_kwargs {"dtype": "bfloat16", "tokenizer_mode": "auto", "trust_remote_code": false, "seed": 0, "enforce_eager": false}
# INFO 06-11 15:16:18 [vllm_service.py:210] Server is healthy at http://127.0.0.1:41109/health
# INFO 06-11 15:16:18 [vllm_service.py:402] Started 1 server(s) listening on 127.0.0.1:41109

# %%
import pandas as pd
from src.data import DF_Batcher

ds_eval = pd.read_csv("../tests/test_responses.csv")
dl_eval = DF_Batcher(ds_eval, batch_size=50, shuffle=False)

# %%
eval_results = []

for evaluator in evaluators:
    print(f"Running evaluator: {evaluator.name}")
    results = evaluator.evaluate(dl_eval)
    eval_results.append(results)
    print(f"Results: {results}")
# Out:
# Running evaluator: PKU-Alignment/beaver-7b-v1.0-cost + meta-llama/Llama-2-7b-chat-hf
# Evaluating PKU-Alignment/beaver-7b-v1.0-cost + meta-llama/Llama-2-7b-chat-hf:   0%|          | 0/11 [00:00<?, …
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       3 for evaluator in evaluators:
#       4     print(f"Running evaluator: {evaluator.name}")
# ----> 5     results = evaluator.evaluate(dl_eval)
#       6     eval_results.append(results)
#       7     print(f"Results: {results}")
#
# File ~/source/llm-iml/src/eval/evaluator.py:59, in Evaluator.evaluate(self, dl_eval)
#      56 num_samples = 0
#      58 for batch_data in tqdm(dl_eval, desc=f"Evaluating {self.name}", disable=self.silent, leave=False):
# ---> 59     batch_metric = self.process_batch(batch_data)
#      60     total_metric += batch_metric.sum().item()
#      61     num_samples += batch_metric.size(0)
#
# File ~/source/llm-iml/src/eval/evaluator.py:100, in MultiEvaluator.process_batch(self, data)
#      98     batch_metric = evaluator.process_batch(data)
#      99     metrics.append(batch_metric)
# --> 100 return self.combine_fn(metrics)
#
# Cell In[2], line 47, in <lambda>(res)
#       7 from src.eval.beaver_evaluator import BeaverEvaluator
#       8 from gserve.configs import ServeConfig, LLMConfig
#      11 evaluators = [
#      12     # HarmbenchEvaluator(
#      13     #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
#      14     #     use_context=False,
#      15     #     silent=False,
#      16     # ),
#      17     # LlamaGuardEvaluator(
#      18     #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=None, client_timeout=60, verbose=True),
#      19     #     # llm_config=LLMConfig(model_name="meta-llama/Llama-Guard-4-12B", max_model_len=4096),
#      20     #     model_name="meta-llama/Llama-Guard-3-1B",
#      21     #     silent=False,
#      22     # ),
#      23     # StrongRejectEvaluator(
#      24     #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
#      25     #     binary_thresh=0.5,
#      26     #     silent=False,
#      27     # ),
#      28     # BeaverEvaluator(
#      29     #     device_map="cuda:1",
#      30     #     binary_thresh=None,
#      31     #     silent=False,
#      32     #     compile=False,
#      33     # ),
#      34     MultiEvaluator(
#      35         [
#      36             BeaverEvaluator(
#      37             device_map="cuda:0",
#      38             binary_thresh=None,
#      39             silent=False,
#      40             compile=False,
#      41             ),
#      42                 LlamaEvaluator(
#      43                 serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
#      44                 silent=False,
#      45             ),
#      46         ],
# ---> 47         combine_fn = lambda res: (res[0] > 5) * res[1]
#      48     )
#      49     # LlamaEvaluator(
#      50     #     serve_config=ServeConfig(gpu_ids=[1], startup_timeout=5 * 60, client_timeout=60),
#      51     #     silent=False,
#      52     # ),
#      53     # TemplateEvaluator(
#      54     #     silent=False,
#      55     # ),
#      56 ]
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %%
eval_results = []

for evaluator in evaluators:
    print(f"Running evaluator: {evaluator.name}")
    results = evaluator.evaluate(dl_eval)
    eval_results.append(results)
    print(f"Results: {results}")

# %%
eval_results = []

for evaluator in evaluators:
    print(f"Running evaluator: {evaluator.name}")
    results = evaluator.evaluate(dl_eval)
    eval_results.append(results)
    print(f"Results: {results}")

# %%
eval_results = []

for evaluator in evaluators:
    print(f"Running evaluator: {evaluator.name}")
    results = evaluator.evaluate(dl_eval)
    eval_results.append(results)
    print(f"Results: {results}")
